# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\sande\\Desktop\\python notes'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1. march practice .ipynb',
#  '15 March.ipynb',
#  '21 March.ipynb',
#  '21feb.ipynb',
#  '22 march.ipynb',
#  '22feb.ipynb',
#  '23 march modules.ipynb',
#  '23feb.ipynb',
#  '24 feb.ipynb',
#  '27 feb .ipynb',
#  '28 feb.ipynb',
#  '2march .ipynb',
#  '2nd day practice home work.ipynb',
#  '8 march.ipynb',
#  'Data type practice.ipynb',
#  'first assignment.ipynb',
#  'Python Course with Notes.zip',
#  'while loop practice.ipynb']

# %%
os.chdir('C:\\Users\\sande\\Downloads')

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '1.py',
#  '12313.jpg',
#  '234548',
#  '2447928310_floating_in_space_by_visualdon.zip',
#  '2nd assignment on dictionaries.ipynb',
#  '3 march-Copy1.ipynb',
#  '3 march.ipynb',
#  '60kb scan image sonu.jpg',
#  '8 march.ipynb',
#  'Alan Walker - The Spectre.mp3',
#  'built-in functions in python (1).ipynb',
#  'built-in functions in python (2).ipynb',
#  'built-in functions in python (3).ipynb',
#  'built-in functions in python.ipynb',
#  'built-in functions in python.pdf',
#  'ChromeSetup.exe',
#  'desktop.ini',
#  'Dictionary Exercise.txt',
#  'dictionary second assignment .ipynb',
#  'english signature.jpg',
#  'Exercises Dict.ipynb',
#  'hindi signature.jpg',
#  'if-else (1).docx',
#  'if-else (2).docx',
#  'if-else.docx',
#  'john-fowler-03Pv2Ikm5Hk-unsplash.jpg',
#  'list assignment 5 march .ipynb',
#  'list exercises.txt',
#  'module.py',
#  'mysql-installer-community-8.0.28.0.msi',
#  'pexels-piccinng-3075993.jpg',
# ...

# %%
os.stat('if-else.docx')
# Out:
# os.stat_result(st_mode=33206, st_ino=562949953727069, st_dev=3559920211, st_nlink=1, st_uid=0, st_gid=0, st_size=492120, st_atime=1645622000, st_mtime=1645621956, st_ctime=1645621951)

# %%
import time

# %%
time.ctime(1645621951)
# Out:
# 'Wed Feb 23 18:42:31 2022'

# %%
os.rename( 'if-else.docx','jb')

# %%
os.remove('jb')

# %%
for one,two,three in os.walk('.'):
    print(one)
    print(two)
    print(three)
    print()
# Out:
# .
# ['.ipynb_checkpoints', '234548', 'Softprober.com_Wallpaper_Engine_1.1.341']
# ...
